# %% [markdown]
# <a href="https://colab.research.google.com/github/jasmineshaik2295/zeta/blob/main/toyoto_mlr_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
import pandas as pd
from google.colab import files
uploaded  = files.upload()
file_name = list(uploaded.keys())[0]
Toyoto_Corrola = pd.read_csv(file_name)
# Out:
#      <input type="file" id="files-5a456356-47cf-4cf0-8161-bfdd872e04be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a456356-47cf-4cf0-8161-bfdd872e04be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded  = files.upload()
file_name = list(uploaded.keys())[0]
toyoto = pd.read_csv(file_name)
# Out:
#      <input type="file" id="files-67987651-3119-42c0-a284-362e5919fbbc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67987651-3119-42c0-a284-362e5919fbbc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Toyoto_Corrola.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-888bdfa3a1ec> in <cell line: 0>()
# ----> 1 Toyoto_Corrola.isnull().sum()
#
# NameError: name 'Toyoto_Corrola' is not defined

# %%
toyoto.shape
# Out:
# (1436, 10)

# %%
toyoto.isnull().sum()
# Out:
# Id           0
# Model        0
# Price        0
# Age_08_04    0
# KM           0
# HP           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
numerical_columns = toyoto.select_dtypes(include=['number']).columns
correlation_matrix = toyoto[numerical_columns].corr()
sns.set_style(style='darkgrid')
sns.pairplot(toyoto[numerical_columns])
print(correlation_matrix)
# Out:
#                  Id     Price  Age_08_04        KM        HP     Doors  \
# Id         1.000000 -0.738250   0.906132  0.273298 -0.109375 -0.130207
# Price     -0.738250  1.000000  -0.876590 -0.569960  0.314990  0.185326
# Age_08_04  0.906132 -0.876590   1.000000  0.505672 -0.156622 -0.148359
# KM         0.273298 -0.569960   0.505672  1.000000 -0.333538 -0.036197
# HP        -0.109375  0.314990  -0.156622 -0.333538  1.000000  0.092424
# Doors     -0.130207  0.185326  -0.148359 -0.036197  0.092424  1.000000
# Cylinders       NaN       NaN        NaN       NaN       NaN       NaN
# Gears     -0.043343  0.063104  -0.005364  0.015023  0.209477 -0.160141
# Weight    -0.414500  0.581198  -0.470253 -0.028598  0.089614  0.302618
#
#            Cylinders     Gears    Weight
# Id               NaN -0.043343 -0.414500
# Price            NaN  0.063104  0.581198
# Age_08_04        NaN -0.005364 -0.470253
# KM               NaN  0.015023 -0.028598
# HP               NaN  0.209477  0.089614
# ...

# %%
import statsmodels.formula.api as smf
model = smf.ols('MPG~WT+VOL+SP+HP',data=cars).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39     try:
# ---> 40         return f(*args, **kwargs)
#      41     except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     178         code = compile(expr, source_name, "eval", self.flags, False)
# --> 179         return eval(code, {}, VarLookupDict([inner_namespace] + self._namespaces))
#     180
#
# <string> in <module>
#
# NameError: name 'VOL' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-14-f9982a207683> in <cell line: 0>()
# ----> 1 model = smf.ols('MPG~WT+VOL+SP+HP',data=toyoto).fit()
#
# ...

# %%
print(toyoto.columns)
# Out:
# Index(['Id', 'Model', 'Price', 'Age_08_04', 'KM', 'HP', 'Doors', 'Cylinders',
#        'Gears', 'Weight'],
#       dtype='object')

# %%
import statsmodels.formula.api as smf
model = smf.ols('Price~KM+HP+Gears+Weight',data=toyoto).fit()

# %%
model.params
# Out:
# Intercept   -33108.190773
# KM              -0.051058
# HP              19.346789
# Gears          823.344168
# Weight          38.449870
# dtype: float64

# %%
print(model.tvalues,'\n',model.pvalues)
# Out:
# Intercept   -17.605309
# KM          -31.835540
# HP            4.695940
# Gears         2.676241
# Weight       35.700191
# dtype: float64
#  Intercept     5.963786e-63
# KM           1.332838e-168
# HP            2.908442e-06
# Gears         7.530299e-03
# Weight       3.747848e-200
# dtype: float64

# %%
(model.rsquared,model.rsquared_adj)
# Out:
# (0.6531449815011297, 0.6521754356772335)
